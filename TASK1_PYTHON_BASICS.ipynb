# %%
print("GENAI_TASK 1 - RUTHVIK CHOWDARY ")
# Out:
# GENAI_TASK 1 - RUTHVIK CHOWDARY

# %%
#1.1 list
products = ["mobile","clothes","books","laptops","watches","combs"]

# %%
#1.2
sample_product = ["moblie",20000,"electronics"]

# %%
#1.3
print(products[1],products[-1])
# Out:
# clothes combs

# %%
#1.4
products.append("face wash")
products.append("mixer")

print(products)
# Out:
# ['mobile', 'clothes', 'books', 'laptops', 'watches', 'combs', 'face wash', 'mixer']

# %%
#2.1 set
categories_list = {"electronics","fashions","stationary","electronics","accessories","cosmetics","cosmetics","electronics"}
categories =set(categories_list)# to remove dublicates 
categories
# Out:
# {'accessories', 'cosmetics', 'electronics', 'fashions', 'stationary'}

# %%
#2-2
categories.add("electronics")
categories# no duplicates
# Out:
# {'accessories', 'cosmetics', 'electronics', 'fashions', 'stationary'}

# %%
#2-2
category_name = input("Enter category: ").strip().lower()  # we can enter the input in search bar
print(category_name in categories)
# Out:
# False

# %%
#3.1 dict
price_dict = {"mobile": 20000,
              "clothes":2000,
              "books":200,
              "laptops":200000,
              "watches":15000,
              "combs":20}

# %%
#3.2
price_dict["milk"]=10
price_dict
# Out:
# {'mobile': 20000,
#  'clothes': 2000,
#  'books': 200,
#  'laptops': 200000,
#  'watches': 15000,
#  'combs': 20,
#  'milk': 10}

# %%
price_dict.pop("milk")
price_dict
# Out:
# {'mobile': 20000,
#  'clothes': 2000,
#  'books': 200,
#  'laptops': 200000,
#  'watches': 15000,
#  'combs': 20}

# %%
#3.3
avg = sum(price_dict.values())/len(price_dict)
avg
# Out:
# 39536.666666666664

# %%
#4.1
#1.1
products = ["mobile","clothes","books","laptops","watches","combs"]
catlog =(
    ("mobile",20000,"electronics"),
    ("cloths",15000,"fashion")
)

# %%
#4.2
categories_products ={
        "electronics" :["mobile","laptops"],
        "stationary" : ["books"],
        "comsmetics":["comb"]
}

# %%
#4.3
max(categories_products,key=lambda x: len(categories_products[x]))
# Out:
# 'electronics'
