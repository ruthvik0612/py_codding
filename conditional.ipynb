# %% [markdown]
# ## IF problems

# %%
# number is +ve or -ve
number = int(input("Enter the number :"))

if number >= 0:
    print("IT'S +VE")
else:
    print("IT'S -VE")
# Out:
# IT'S +VE

# %%
#check weather the string is empty or not 
str = {}
if len(str) == 0 :
    print("Its empty")
else:
    print("Its not empty")
# Out:
# Its empty

# %%
#get +ve or -ve or zerp 
num = int(input("Enter a Number:"))

if num < 0:
    print("its -ve")
if num == 0:
    print("its zero")
if num > 0:
    print("its +ve")
# Out:
# its +ve

# %%
# if num is multiple of both 3 and 5

num1 = int(input("Enter a number:"))

if num1%3 == 0 and num1%5 == 0:
    print("its multiple of  3 and 5")
# Out:
# its multiple of  3 and 5

# %%
# if a number is perfect sqaure or not
import math
num = int(input("enter a number :")) 

square = math.sqrt(num)*math.sqrt(num)

if num  == square:
    print("its a perfect square")
else:
    print("not a perfect square")
###########################################################################################################

i = 1

while  i*i <= num:
    if i*i == num:
        print("perfect square")
        break
    i += 1
else:
    print("not a square")
# Out:
# its a perfect square
# perfect square

# %%
num = int(input("enter a number"))

if num % 2 == 0 and num % 3 == 0:
    print("Its divisible by both 2 and 3")

# %%
# PERFECT CUBE BUT WITH LOOPS 

num = int(input("Enter a number: "))

i = 1
while i * i * i <= num:
    if i * i * i == num:
        print("Perfect cube")
        break
    i += 1
else:
    print("Not a perfect cube")
# Out:
# Perfect cube

# %%
#multiple of 4 or not 
num  =  int(input("enter a number "))

if num % 4 == 0:
    print("multiple of 4")
# Out:
# multiple of 4

# %% [markdown]
# ## if else problems

# %%
year = int(input("enter the year"))

if year % 400 == 0  :
        print("leap year ")
elif year % 100 == 0:
        print("not a leap")
elif year % 4 == 0:
        print("leap")

else:
        print("not a leap")
# Out:
# leap

# %%
# to check the given charcter is owel or not 
a = str(input("enter a char "))

if a.lower()  == "a" or "e" or "i" or "o" or "u":
    print("the char is vowel")
else:
    print("not a vowels")
# Out:
# the char is vowel

# %%
# the  give is a  year century year or not means end with 00

a = int(input("enter a number"))

if a%100 == 0:
    print("its a century year")
else:
    print("not ")
# Out:
# its a century year

# %%
#prime number 
num = int(input("enter  a number "))

if num <= 1:
    print('not a prime')
else:
    for i in range (2,num):
        if num% i == 0:
            print("not prime")
            break
    else: 
        print("prime")
# Out:
# prime

# %%
# vote eligible 
num = int(input("age "))
if num >= 18:
    print("eligible")
else:
    print("not eligible")
# Out:
# not eligible

# %%
#num is 0,+ve or -vd
num = int(input("number "))

if num < 0:
    print("-ve")
elif num == 0:
    print("zero")
else:
    print("+ve")
# Out:
# -ve

# %%
#greatest of 2

num1 = int(input("num1"))
num2 =  int(input("num2"))

if num1 > num2 :
    print(num1)
else:
    print(num2)
# Out:
# 21

# %%
# to check weather char or not 
s = str(input("char"))

if 'a' <= s.lower() <= 'z':
    print("char")
else: 
    print("not  a char")
# Out:
# not  a char

# %%
# highest of 3 
a = int(input("enter a number"))
b = int(input("enter number"))
c =  int(input("enter a number"))

if a > b :
    print(a)
elif b > c :
    print(b)
elif c > a :
    print(c)
# Out:
# 34

# %%
#palindrome
s =  "rcr"
s1 = s[::-1]

if s1 == s:
    print("palindrome")
else:
    print("not a palindrome")
# Out:
# palindrome

# %%
#detremines the sign of the output
a = int(input("enter a number "))
b =  int(input("enter a number "))

if a  ==  0 and  b ==  0  :
    print("zero")
elif  (a > 0 and b > 0 ) or ( a < 0 and b< 0) :
    print("+ve")
else:
    print("-ve")
# Out:
# +ve

# %%
#multiple of 7 or not 
num = int(input("enter a number"))

if num%7 == 0:
    print("mulitiple")
else:
    print("not A  Multiple")
# Out:
# mulitiple

# %%
#calculate the absolute value of a given number 
# if -ve converts to postive , if its +ve keep it+ve
a = int(input("enter a number"))

if  a < 0 :
    a = a*-1
    print(a)
else:
    print(a)
# Out:
# 23

# %% [markdown]
# ## if elif -elif problems

# %%
#convert Fahrenheit to Celsius

temp = int(input("enter a the temprature"))
degree = str(input("enter the degrees either  f or c"))

if degree == "c" :
    far = (((9/5) *temp) + 32)
    print ( f"the temp in Fahrenheit is  {far}")
else:
    cel = ((5/9) *(temp - 32))
    print(f"the temp in  Celsius is {cel} ")
# Out:
# the temp in Fahrenheit is  212.0

# %%
# simple calculator 
a = int(input("enter the frist number"))
b = int(input("enter the second number"))

operation = str(input("ENTER WHICH OPRATION NEEDS TO BE PERFROMED  *,-,+,/ "))

if operation == "+":
    print(a+b)
elif operation == "-":
    print(a-b)
elif operation == "/":
    print(a/b)
elif operation == "*":
    print(a*b)
# Out:
# 144

# %%
#guess the number game 
import random

a = int(input("enter a number"))
b =random.randint(1,9)

if a == b:
    print(f"the random number is {b}")
    print("crt guess")
else:
    print("better luck nxt time")
    print(f"the random number is {b}")
# Out:
# the random number is 4
# crt guess

# %%
#APPLY DISCOUNT ON FINAL PROCE 

price =int(input("enter to total price"))
discount = int(input("enter the discount"))

total_price = price -  price*(discount/100)
print(f"the total price after discout {total_price}")
# Out:
# the total price after discout 1080.0

# %%
#ATM ALLOWS USER TO CHECK BAL AND WITH DRAW MONEY 
bal = 25000 
choice = int(input("enter 1 -> check bal " \
"                     enter 2-> withdraw"))

if choice == 1 :
    print(f"ur account bal is :{bal}")
if choice == 2 :
    amount = int(input("enter amount to with draw"))
    if amount <= bal:
        bal = bal-amount
        print(f"ur remaming balance{bal}")
    else:
        print("please enter less amount insufficent funds")
# Out:
# ur account bal is :25000

# %%
#greets user based in time

from datetime import datetime
current_hour = datetime.now().hour
print(current_hour)
if current_hour >= 0  and current_hour <= 11 :
    print("gud mrg")
elif current_hour >= 12 and current_hour <= 15:
    print("gud afternoon")
elif current_hour >= 16  and current_hour<=17:
    print("gud evg")
else :
    print("gud nyt")
# Out:
# 18
# gud nyt

# %%
#calculate score and print grade validate

# %%
#bmi
#< 18.5 → Underweight ,18.5 – 24.9 → Normal,25 – 29.9 → Overweight,30+ → Obese
weight = float(input("enter weight"))
height = float(input("enter height i meters ex:1.77m"))
bmi = (weight/(height*height))

if bmi < 18.5:
    print("under weight")
elif bmi >18.5 and bmi < 24.9:
    print("normal")
elif bmi >25 and bmi < 30:
    print("over weight")
else :
    print("obese")
# Out:
# obese
