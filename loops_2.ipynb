# %%
for _ in range(3):
    print("#")
# Out:
# #
# #
# #

# %%
i = 0
while i < 3:
    print("cat")
    i +=1
# Out:
# cat
# cat
# cat

# %%
print("cat\n"*3)
# Out:
# cat
# cat
# cat

# %%
while True:
    n = int(input("enter a number"))
    if n > 0:
        break
 
for _ in range(n):
    print("cat")
# Out:
# cat
# cat
# cat
# cat
# cat
# cat
# cat
# cat
# cat
# cat
# cat
# cat

# %%
def main():
    meow(3)
def meow(n):
    for _ in range(n):
        print("meow")
main()#prints 3 times
meow(4)# 4 times
# Out:
# meow
# meow
# meow
# meow
# meow
# meow
# meow

# %%
def get_number():
    number = int(input("enter a number")) # gets the number 
    if number > 0:
        return number


def meow(number): 
    for _ in range(number):
        print("meow")
n = get_number()
meow(n)# passes number to meowfunction
# Out:
# meow
# meow

# %%
students = ["ruthvik ","chowdary","Sukhavasi"]

for student in students:
    print(student)
# Out:
# ruthvik
# chowdary
# Sukhavasi

# %%
for i in range (len(students)):
    print(i+1,students[i])
# Out:
# 1 ruthvik
# 2 chowdary
# 3 Sukhavasi

# %%
#diT  # the data is store in the form of key value pairs, dit by default will shoe the value if we call key
kids = {
    "ruthvik " : "AP",
    "chowdary" : "KA",
    "Sukhavasi": "TS",
    }

for kid in kids :
    print(kid,kids[kid], sep = " lives in -->") # we have called kids , and then kids name  -> key automatically bringd palces
# Out:
# ruthvik  lives in -->AP
# chowdary lives in -->KA
# Sukhavasi lives in -->TS

# %%
# what if we want more or we have more lists 

kido =[ 
    {"name": "Alice" ,"location":"Karnataka","Phone_no":8217},
     {"name": "bob" ,"location":"Ap","Phone_no":8223},
     {"name": "Ali" ,"location":"TS","Phone_no":823},
    ] 

for kid in kido :
    print(kid["name"],  kid["location"] ,  kid["Phone_no"])
# Out:
# Alice Karnataka 8217
# bob Ap 8223
# Ali TS 823

# %%
# using basic funtion and loops 

def main():
    height = int(input("enter the height of #'s"))
    return height 

def print_column(height):
    for _ in range(height):
        print("#")
#n  = main()
#print_column(n)  
print_column(3)
# Out:
# #
# #
# #

# %%
# WE ARE GNG TO PRINT ROW 4 TIMES

def main():
    print_row(4)

def print_row(width):
    print("?" * width) # --> print 4 times

main()
# Out:
# ????

# %%
# my code 
def main():
    print_square(4)
def print_square(size):
    for i in range(size):
        print("#"*size)
main()
# Out:
# ####
# ####
# ####
# ####

# %%
#tutors code 
def main():
    print_square(4)
def print_square(size):
    for i in range(size): # for each row in square
        for j in range(size): #for each brick in a row
            print("#",end = " ") # print brick 
        print()# print new line after the one row
main()
# Out:
# # # # #
# # # # #
# # # # #
# # # # #
