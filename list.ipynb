# %% [markdown]
# ## problems on list

# %%
#reverse a list
a =[1,2,3,4,5,6,7,8]
a.reverse()
print(a)

b =a[::-1] # method 2 to reverse 
b
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
s = "ram"
s1 = s[::-1]
s1
# Out:
# 'mar'

# %%
# remove duplicates 

a = [1,2,2,2,3,3,4,5,6]
a = list(set(a))
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# find imn and max

a = [12,21,121,2,12,3,2423434,3]
print(min(a))
max(a)
# Out:
# 2
# 2423434

# %%
#sort in asc and desc
a = [12,21,121,2,12,3,2423434,3]
asc = sorted(a)
print(asc)
desc = sorted(a,reverse=True)
desc
# Out:
# [2, 3, 3, 12, 12, 21, 121, 2423434]
# [2423434, 121, 21, 12, 12, 3, 3, 2]

# %%
# CHECK WEATHER THE LIST IS EMPTY OR NOT
list =[12,13]

if not list:
    print("empty")
else:
    print("not empty")
# Out:
# not empty

# %%
# FIND THE INDEX OF SPECIFIC ELEMENT 
lst = [1,2,3,4,5,6]
a = int(input("Enter the elements which u want to find:"))

for index , value  in enumerate(lst):
    if  value == a :
        print("emenent found AT INDEX ", index)
        break
else:
    print ("not in list")
# Out:
# emenent found AT INDEX  5

# %%
#merge 2 list 
s = [1,2,3,3,4]
b = [1,2,2,2,2,4]
c = s+b
print(c)
print(s,b)
# Out:
# [1, 2, 3, 3, 4, 1, 2, 2, 2, 2, 4]
# [1, 2, 3, 3, 4] [1, 2, 2, 2, 2, 4]

# %%
#sum of all elements in a list 
lst = [1,2,3,4,5]
