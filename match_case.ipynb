# %%
num = int(input("enter a  number "))
case = int(input("enter a case number "))
match case:
    case 1:
        ans = num + 10
        print(ans)
    case 2:
        ans = num - 10
        print(ans)
        if ans < 0:
                print("-ve number")
        else: 
                print("+ve number")
# Out:
# 90
# +ve number
